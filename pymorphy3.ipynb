# %% [markdown]
# <a href="https://colab.research.google.com/github/nam3user/comp_ling-course/blob/main/pymorphy3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymorphy3 pymorphy3-dicts-ru
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 55.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# Ссылка: https://pymorphy2.readthedocs.io/en/stable

# %%
from pymorphy3 import MorphAnalyzer
morph = MorphAnalyzer()

word = "кот"
parsed = morph.parse(word)[0]
print(f"Грамматика: {parsed.tag}")
# Out:
# Грамматика: NOUN,anim,masc sing,nomn
